# %% [markdown]
# Дашборд, выполненный на BI платформe Datalens Yandex, для интерактивной работы доступен по ссылке, указанной ниже.

# %%
# %%html
# https://datalens.yandex/lfocrews85zu9
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
#     <meta charset="utf-8">
#     <title>Prices for residential buildings in Ames, Iowa in the USA</title>
#     <link rel="icon" type="image/png" sizes="48x48" href="/yc-favicon.png">
#     <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/i18n/ru-ru.1a4491db.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/runtime.9a14d92e.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/vendors.0b0a4593.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/5720.e7836bff.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/755.a36b8e22.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/6439.f5926e38.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/5372.85769826.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/1045.1126c79a.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/1006.314e6806.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/1543.a63f12c2.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/5514.f40442ab.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/6285.2a5afce3.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="https://yastatic.net/s3/cloud/datalens/static/freeze/js/public.b2e12323.js" crossorigin="anonymous" as="script" nonce="ovDA0OuCKWaZiConsDUbKg==" rel="preload">
# <link href="/yc.site.webmanifest" crossorigin="use-credentials" rel="manifest" type="application/manifest+json">
# <link href="/yc-favicon.svg" rel="icon" type="image/svg+xml">
# <link href="/yc-favicon.ico" rel="icon" type="image/icon" sizes="any">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <meta name="theme-color" content="#5282FF">
# <link rel="stylesheet" href="https://yastatic.net/s3/cloud/datalens/static/freeze/css/5720.6bc911b9.css">
# <link rel="stylesheet" href="https://yastatic.net/s3/cloud/datalens/static/freeze/css/755.978baa0b.css">
# <link rel="stylesheet" href="https://yastatic.net/s3/cloud/datalens/static/freeze/css/6439.062c3634.css">
# <link rel="stylesheet" href="https://yastatic.net/s3/cloud/datalens/static/freeze/css/5372.75d17828.css">
# <link rel="stylesheet" href="https://yastatic.net/s3/cloud/datalens/static/freeze/css/1543.079173c4.css">
# <link rel="stylesheet" href="https://yastatic.net/s3/cloud/datalens/static/freeze/css/6285.ff7d99da.css">
# <link rel="stylesheet" href="https://yastatic.net/s3/cloud/datalens/static/freeze/css/public.1efe1293.css">
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/i18n/ru-ru.1a4491db.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/runtime.9a14d92e.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/vendors.0b0a4593.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/5720.e7836bff.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/755.a36b8e22.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/6439.f5926e38.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/5372.85769826.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/1045.1126c79a.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/1006.314e6806.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/1543.a63f12c2.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/5514.f40442ab.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/6285.2a5afce3.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script src="https://yastatic.net/s3/cloud/datalens/static/freeze/js/public.b2e12323.js" defer="true" crossorigin="anonymous" nonce="ovDA0OuCKWaZiConsDUbKg=="></script>
# <script nonce="ovDA0OuCKWaZiConsDUbKg==">window.__APP_VERSION__ = "1021-0.1212.0"</script>
# <script nonce="ovDA0OuCKWaZiConsDUbKg==">window.__PUBLIC_PATH__ = "https://yastatic.net/s3/cloud/datalens/static/freeze/"</script>
# <script nonce="ovDA0OuCKWaZiConsDUbKg==">window.__DATA__ = {"DL":{"deviceType":"desktop","requestId":"e88e2c6b-045e-4572-b540-042ad3062e67","env":"production","installationType":"public","serviceName":"Yandex DataLens","user":{"lang":"ru"},"userSettings":{"language":"ru"},"iamUserId":"","clouds":[],"endpoints":{"public":"https://datalens.yandex","gateway":"/gateway","charts":"/charts","connections":"https://datalens.yandex.ru/connections","dataset":"https://datalens.yandex.ru/datasets","wizard":"https://datalens.yandex.ru/wizard","ql":"https://datalens.yandex.ru/ql","dash":"https://datalens.yandex.ru/dashboards","uploader":"https://upload.datalens.yandex.ru","navigation":"https://datalens.yandex.ru/navigation","widgets":"https://datalens.yandex.ru/widgets","extPassportOAuth":"https://oauth.yandex.ru","datalensDocsRu":"https://cloud.yandex.ru/docs/datalens","datalensDocsEn":"https://cloud.yandex.com/docs/datalens","support":"https://console.cloud.yandex.ru/support","console":"https://console.cloud.yandex.ru","cloudRu":"https://cloud.yandex.ru","cloudEn":"https://cloud.yandex.com","illustrationStorage":"https://storage.yandexcloud.net/console-static/illustrations-v2"},"features":{"AddDemoWorkbook":false,"AsideHeaderEnabled":false,"AuthUpdateWithTimeout":false,"BackofficeBanner":false,"BackofficePromo":false,"ChartEditorDeveloperModeCheck":false,"chartkitAlerts":false,"CloudMode":false,"CollectionsAccessEnabled":false,"CollectionsEnabled":false,"Comments":false,"CopyEntriesToWorkbook":false,"crawlerPromo":false,"CustomColorPalettes":false,"D3Visualizations":false,"DashAutorefresh":false,"DashBoardAccessDescription":false,"dashBoardGlobalParams":false,"DashBoardSupportDescription":false,"DashBoardWidgetParamsStrictValidation":false,"DatasetsRLS":false,"emptySelector":false,"EnableAutocreateDataset":false,"EnableChartEditor":false,"EnableCustomMonitoring":false,"EnableDashChartStat":false,"EnableFavoritesNameAliases":false,"EnableMobileHeader":false,"EnablePromoJsSdk":false,"EnablePublishEntry":false,"EnableShareWidget

# %% [markdown]
# ![image.png](data:image/png;base64,...)
