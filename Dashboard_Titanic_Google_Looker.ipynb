# %% [markdown]
# Дашборд, выполненный на BI платформe Google Looker (Google Data Studio), для интерактивной работы доступен по ссылке, указанной ниже.

# %%
# %%html
# https://lookerstudio.google.com/reporting/5d86681e-1a0b-473a-980b-51096e6e5a0a

# %% [markdown]
# ![image.png](data:image/png;base64,...)
